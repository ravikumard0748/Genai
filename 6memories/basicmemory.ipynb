# %%
# from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

# Model
# llm = ChatOpenAI(model="gpt-4o-mini")
llm  = ChatGoogleGenerativeAI(model = "gemini-2.5-flash")

# Store session memory
store = {}

def get_session_history(session_id: str):
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()
    return store[session_id]

# Wrap model with memory
chain = RunnableWithMessageHistory(
    llm,
    get_session_history
)

# Run
response = chain.invoke(
    "Hi, my name is Ravi",
    config={"configurable": {"session_id": "1"}}
)

print(response.content)
# Out:
# Hi Ravi! Nice to meet you. I'm an AI assistant. How can I help you today?

# %%
res2 = chain.invoke("what is the meaning of my name",    config={"configurable": {"session_id": "1"}}
)

# %%
print(res2.content)
# Out:
# That's a great question, Ravi!
#
# **Ravi** is a beautiful name with a very significant meaning.
#
# *   **Origin:** It originates from Sanskrit and is widely used in India.
# *   **Meaning:** Its most common and prominent meaning is **"Sun"** or **"Sun God."**
#
# In Hindu mythology, Ravi is another name for **Surya**, the Sun God, who is a very important deity associated with light, warmth, energy, life, and knowledge.
#
# So, your name carries connotations of brightness, vitality, power, and importance! It's a strong and positive name.

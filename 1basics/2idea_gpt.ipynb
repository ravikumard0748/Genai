# %%
from dotenv import load_dotenv
load_dotenv()
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
prompt = """
Put yourself as a expert in givning the new ideas belonging to make a money and you have the expertised in the economics,tech and business
\n you need Top 10 ideas that must be implemented in the bengaluru to get a huge revenue and the make high profit
\n Now give the top 10 ideas with the serial no with its  
 idea name and its one line core function \n
 example :
\n 1.Hotel - near the it parks with the econimic cost 

"""
llm = ChatGoogleGenerativeAI(model = "gemini-2.5-flash")

# %%
result = llm.invoke(prompt)

# %%
print(result.content)
# Out:
# As an expert blending economics, tech, and business insights, here are the Top 10 ideas tailored for Bengaluru to generate significant revenue and high profits, leveraging its unique ecosystem:
#
# 1.  **AI-Optimized Urban Mobility Network**
#     *   Develop a platform using AI to manage and optimize multi-modal last-mile connectivity, integrating electric vehicles, ride-sharing, and smart traffic solutions.
#
# 2.  **Smart Co-Living & Integrated Services**
#     *   Establish premium, tech-enabled co-living spaces offering integrated services like smart home automation, high-speed internet, laundry, food subscriptions, and community events for young professionals.
#
# 3.  **Dark Kitchen Hubs with Virtual Brands**
#     *   Build large-scale, shared dark kitchen infrastructure optimized for multiple virtual restaurant brands, leveraging AI for menu optimization, supply chain, and delivery logistics across the city.
#
# 4.  **Tech-Enabled Waste-to-Value Plants**
# ...

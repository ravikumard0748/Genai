# %%
from langchain_community.document_loaders import TextLoader
# Out:
# WARNING:tensorflow:From C:\Users\ravik\AppData\Roaming\Python\Python312\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_community.tools.wikipedia.tool import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper
from langchain import hub

# ✅ Correct imports for LangChain 1.2.x
from langchain_core.agents import AgentExecutor
from langchain.agents.react.agent import create_react_agent

# 1. Setup LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

# 2. Setup Tools
api_wrapper = WikipediaAPIWrapper(top_k_results=2, doc_content_chars_max=1000)
wiki = WikipediaQueryRun(api_wrapper=api_wrapper)
tools = [wiki]

# 3. Pull the ReAct prompt
prompt = hub.pull("hwchase17/react")

# 4. Create Agent
agent = create_react_agent(llm, tools, prompt)

# 5. Wrap in AgentExecutor
agent_executor = AgentExecutor(
    agent=agent,
    tools=tools,
    verbose=True,
    handle_parsing_errors=True,
    max_iterations=5
)

# 6. Run
response = agent_executor.invoke({"input": "Who is Elon Musk?"})
print(response["output"])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[38], line 4
#       2 from langchain_community.tools.wikipedia.tool import WikipediaQueryRun
#       3 from langchain_community.utilities import WikipediaAPIWrapper
# ----> 4 from langchain import hub
#       6 # ✅ Correct imports for LangChain 1.2.x
#       7 from langchain_core.agents import AgentExecutor
#
# ImportError: cannot import name 'hub' from 'langchain' (C:\Users\ravik\AppData\Roaming\Python\Python312\site-packages\langchain\__init__.py)

# %%
import langchain; print(langchain.__version__)
# Out:
# 1.2.10

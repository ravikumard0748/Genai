# %%
from transformers import pipeline

# %%
#  in this we need to tell the task that we are going to do the task is basically in the hugging face hub itself

senti_model = pipeline(task="sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# ...

# %%
senti_model("This was a amazing movie")[0]['score']
# Out:
# 0.9998811483383179

# %%
type(result)
# Out:
# list

# %%
result[0]
# Out:
# {'label': 'POSITIVE', 'score': 0.9998811483383179}

# %%
#  the model parameter is used to fetch the correct model that we wanted to use
senti_model2 = pipeline(task = "sentiment-analysis",model = "cardiffnlp/twitter-roberta-base-sentiment-latest")
# Out:
# config.json:   0%|          | 0.00/929 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/501M [00:00<?, ?B/s]
# RobertaForSequenceClassification LOAD REPORT from: cardiffnlp/twitter-roberta-base-sentiment-latest
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
# roberta.pooler.dense.weight     | UNEXPECTED |  |
# roberta.pooler.dense.bias       | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
senti_model2("today's session is amazing")
# Out:
# [{'label': 'positive', 'score': 0.987335205078125}]

# %%
from transformers import pipeline

# %%
translator = pipeline(task = "translation_en_to_fr",model="google-t5/t5-small")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# C:\Users\ravik\AppData\Roaming\Python\Python312\site-packages\huggingface_hub\file_download.py:144: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ravik\.cache\huggingface\hub\models--google-t5--t5-small. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
translator("how to make a brownine cake")
# Out:
# [{'translation_text': 'comment faire un gâteau à la brunine'}]

# %%
document = open(r"C:\Users\ravik\OneDrive\Desktop\Learnings\Genai\cse1.txt").read()

# %%
document
# Out:
# 'An introduction to Computer Science and its History\nMuhammed Nyeem Hassan1\nShah Mohammad Omer Faruqe Jubaer2\n\nAbstract: The field of computer science is one of the most rapidly growing and well-paying in the world. However, the number of teachers and students interested in Computer Science is dwindling. This is mostly determined by how well students are exposed to technology and resources, as well as whether or not they are encouraged to pursue careers in computer science. Students who are not interested in computer science benefit from computer science education as well. So the primary aim of this research paper is to give access to general students to know about Computer Science. The rise of the digital world necessitates the development of logical thinking and problem-solving skills, both of which are included in the computer science curriculum. Students, regardless of their field of study, must be enthusiastic about using computers, whether it\'s to create a file, write a pa
# ...

# %%
qa = pipeline(task="question-answering",model="deepset/roberta-base-squad2")
# Out:
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# C:\Users\ravik\AppData\Roaming\Python\Python312\site-packages\huggingface_hub\file_download.py:144: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ravik\.cache\huggingface\hub\models--deepset--roberta-base-squad2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
qa(
    {'question':"who is father of computer sceince",
    'context': document
    }
)
# Out:
# C:\Users\ravik\AppData\Roaming\Python\Python312\site-packages\transformers\pipelines\question_answering.py:391: FutureWarning: Passing a list of SQuAD examples to the pipeline is deprecated and will be removed in v5. Inputs should be passed using the `question` and `context` keyword arguments instead.
#   warnings.warn(
# {'score': 0.02898874692618847,
#  'start': 10607,
#  'end': 10624,
#  'answer': 'Wilhelm Schickard'}

# %%
qa(
    {
        'question' : "who is invented computer",
        'context' : document
    }
)
# Out:
# C:\Users\ravik\AppData\Roaming\Python\Python312\site-packages\transformers\pipelines\question_answering.py:391: FutureWarning: Passing a list of SQuAD examples to the pipeline is deprecated and will be removed in v5. Inputs should be passed using the `question` and `context` keyword arguments instead.
#   warnings.warn(
# {'score': 0.5095078945159912,
#  'start': 21367,
#  'end': 21382,
#  'answer': 'George Forsythe'}

# %%
from transformers import pipeline
ner = pipeline(task = "ner",model="dslim/bert-base-NER")
# Out:
# config.json:   0%|          | 0.00/829 [00:00<?, ?B/s]
# C:\Users\ravik\AppData\Roaming\Python\Python312\site-packages\huggingface_hub\file_download.py:144: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ravik\.cache\huggingface\hub\models--dslim--bert-base-NER. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
ne

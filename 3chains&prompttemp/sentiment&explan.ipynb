# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_huggingface import HuggingFaceEndpoint

senti_prompt = PromptTemplate(
    input_variables = ["sentence"],
    template = """
    Analyze the Given string and tell whether it is  positive or negative 
    note Your output must be in the one word either positive or negative
    and the input is {sentence}
    """
)
senti_llm =  ChatGroq(
    model="openai/gpt-oss-120b",   # ✅ Free model
    temperature=0.7
)

# %%
# model 2
reason_prompt = PromptTemplate(
    input = ["sentence","output_from_previous"],
    template = """
    Analyze this given word : {sentence} and tell only the which word causing the result of the sentiment
    analysis to {outuput_from_previous}
    """
)

reason_llm =  ChatGroq(
    model="openai/gpt-oss-120b",   # ✅ Free model
    temperature=0.7
)
reason_chain = reason_prompt | reason_llm | StrOutputParser()

# %%
main_chain = senti_chain | (lambda x : {"output_from_previous" : x}) | reason_chain

# %%
main_chain.invoke({"sentence":"Wow what an amazing view it is"})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 main_chain.invoke({"sentence":"Wow what an amazing view it is"})
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_core\runnables\base.py:3157, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3155                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3156             else:
# -> 3157                 input_ = context.run(step.invoke, input_, config)
#    3158 # finish the root run
#    3159 except BaseException as e:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_core\prompts\base.py:223, in BasePromptTemplate.invoke(self, input, config, **kwargs)
#     221 if self.tags:
#     222     config["tags"] += self.tags
# --> 223 return self._call_with_config(
#     224     self._format_prompt_with_error_handling,
# ...

# %%
from langchain_groq import ChatGroq
from langchain_core.messages import HumanMessage
from dotenv import load_dotenv

load_dotenv()

llm = ChatGroq(
    model="openai/gpt-oss-120b",   # ✅ Free model
    temperature=0.7
)

response = llm.invoke("hell how are you ")
print(response.content)
# Out:
# Hello! I'm doing great, thanks for asking. How can I help you today?
